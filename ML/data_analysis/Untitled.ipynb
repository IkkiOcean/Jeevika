# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("drugs_for_common_treatments.csv")

# %%
filter_otc = data['rx_otc'] == 'OTC'
data_otc = data[filter_otc]

data_otc
# Out:
#                                   drug_name     medical_condition  \
# 76                           Acne Treatment                  Acne
# 100                                 PanOxyl                  Acne
# 101           PanOxyl 10% Acne Foaming Wash                  Acne
# 112                                 Acne-10                  Acne
# 115                                 Acnomel                  Acne
# ...                                     ...                   ...
# 3619                             Asper-Flex  Rheumatoid Arthritis
# 3623  camphor / menthol / methyl salicylate  Rheumatoid Arthritis
# 3654                                Myoflex  Rheumatoid Arthritis
# 3665                   trolamine salicylate  Rheumatoid Arthritis
# 3929                                   Alli           Weight Loss
#
#                           medical_condition_description activity rx_otc  \
# 76    Acne Other names: Acne Vulgaris; Blackheads; B...       1%    OTC
# ...

# %%
filter_preg = data['pregnancy_category'] == 'B'
data_preg = data_otc[filter_preg]
data_preg
# Out:
# /var/folders/kj/8ccbfhn56tgcwgc45d118plh0000gn/T/ipykernel_3419/34412887.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_preg = data_otc[filter_preg]
#                                        drug_name  medical_condition  \
# 1080                                    Dulcolax       Constipation
# 1081                                   bisacodyl       Constipation
# 1099                                    Bisa-Lax       Constipation
# 1102                                   Correctol       Constipation
# 1104                             Fleet Bisacodyl       Constipation
# 1325                                   Humulin N  Diabetes (Type 1)
# 1326                                   Humulin R  Diabetes (Type 1)
# 1328                                   Novolin R  Diabetes (Type 1)
# 1330                               Humulin 70/30  Diabetes (Type 1)
# 1332                                   Novolin N  Diabetes (Type 1)
# ...

# %%
filter_const = data['medical_condition'] == 'Constipation'
data_const = data_otc[filter_const]
data_const
# Out:
# /var/folders/kj/8ccbfhn56tgcwgc45d118plh0000gn/T/ipykernel_3419/1055018912.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_const = data_otc[filter_const]
#                   drug_name medical_condition  \
# 1080               Dulcolax      Constipation
# 1081              bisacodyl      Constipation
# 1087              Metamucil      Constipation
# 1090               FiberCon      Constipation
# 1095               psyllium      Constipation
# 1099               Bisa-Lax      Constipation
# 1102              Correctol      Constipation
# 1104        Fleet Bisacodyl      Constipation
# 1116               Hydrocil      Constipation
# 1117                 Konsyl      Constipation
# 1119               Reguloid      Constipation
# 1123             Equalactin      Constipation
# 1125              Fiber Lax      Constipation
# 1126         Fiber Laxative      Constipation
# 1130  Natural Fiber Therapy      Constipation
# ...
